# %% [markdown]
# #list
# #tuple
# #set
# #dict
# #range

# %%
# LIST

# %%
l = []
l
# Out:
# []

# %%
type(1)
# Out:
# int

# %%
l.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 l.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
l.append(10)

# %%
l.append(20)
l.append(30)
l.append(40)

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l.append(125)
