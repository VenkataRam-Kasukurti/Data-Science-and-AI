# %% [markdown]
# # Exercises

# %% [raw]
# Exercise 1: Store and Print
#
# Create variables for:
#
# .your name
# .age
# .height
# .whether you are a student
#
# Print all values with their data types.

# %%
x = input("your name:")
y = input("age:")
h = input("height")
s = input("whether you are a student")
print(f"my name is 'x')
# Out:
#   Cell In[3], line 5
#     print(f"my name is 'x')
#           ^
# SyntaxError: unterminated f-string literal (detected at line 5)

# %% [raw]
# Exercise 2: Type Identification
# Create 10 variables of different types and print:
#
# .value
# .type
# .id()

# %% [raw]
# Exercise 3: Type Conversion
# Take:
#
# .an integer
# .a float
# .a string number like "25"
# Convert them into other possible types and print results

# %% [raw]
# Exercise 4: Input Practice
# Take user input for:
#
# .name
# .age
# .salary
#
# Then print:
#
# age after 5 years
# salary after 10% increment

# %% [raw]
# Exercise 5: Expression with eval()
# Accept an expression from the user and print the result.
#
# Example input:
# 12 + 5 * 2

# %% [raw]
# Exercise 6: Swap Two Variables
# Swap two numbers:
#
# using third variable
# without third variable

# %% [raw]
# Exercise 7: Area Calculator
# Input length and breadth, print area and perimeter.

# %% [raw]
# Exercise 8: Temperature Converter
# Convert:
#
# Celsius to Fahrenheit
# Fahrenheit to Celsius

# %% [raw]
# Exercise 9: Arithmetic Operations
# Take two numbers and print:
#
# addition
# subtraction
# multiplication
# division
# floor division
# modulus
# power

# %% [raw]
# Exercise 10: Assignment Operators
# Start with a number and apply:
#
# +=
# -=
# *=
# /=
# //=
# %=
# Print after each step.

# %% [raw]
# Exercise 11: Relational Operators
# Input two numbers and compare them using all relational operators.

# %% [raw]
# Exercise 12: Logical Operators
# Input three values:
#
# age
# income
# citizen status
# Check eligibility for a scheme using and, or, not.

# %% [raw]
# Exercise 13: Unary Operator
# Take a number and print:
#
# positive version
# negative version

# %% [raw]
# Exercise 14: Even or Odd
# Check if a number is even or odd using %.

# %% [raw]
# Exercise 15: Largest of Three Numbers
# Find the largest among 3 numbers.

# %% [raw]
# Exercise 16: Leap Year Check
# Check if a year is leap year or not.

# %% [raw]
# Exercise 17: Binary, Octal, Hex
# Input a decimal number and print:
#
# binary
# octal
# hexadecimal

# %% [raw]
# Exercise 18: Bitwise Operations
# Take two integers and print:
#
# &
# |
# ^
# ~
# <<
# >>

# %% [raw]
# Exercise 19: Left Shift Meaning
# Show how left shift changes the value of:
#
# 3
# 5
# 10
# for 1, 2, and 3 positions.

# %% [raw]
# Exercise 20: Odd/Even Using Bitwise
# Check if a number is odd or even using bitwise operator.

# %% [raw]
# Exercise 21: Set or Clear a Bit
# Given a number and bit position:
#
# set that bit
# clear that bit
# toggle that bit

# %% [raw]
# Exercise 22: Count Set Bits
# Count how many 1s are there in binary representation of a number.

# %% [raw]
# Exercise 23: String Basics
# Take a string and print:
#
# first character
# last character
# length
# reversed string

# %% [raw]
# Exercise 24: Count Vowels
# Count vowels in a string.

# %% [raw]
# Exercise 25: Palindrome Check
# Check if a string is palindrome.
#
# Examples:
#
# madam
# radar

# %% [raw]
# Exercise 26: Character Frequency
# Count how many times each character appears.

# %% [raw]
# Exercise 27: Word Count
# Input a sentence and count number of words.

# %% [raw]
# Exercise 28: Replace Spaces
# Replace all spaces in a string with _.

# %% [raw]
# Exercise 29: Upper, Lower, Title
# Input a string and print:
#
# uppercase
# lowercase
# title case
# swapped case

# %% [raw]
# Exercise 30: Remove Duplicates from String
# Example:
#
# input: programming
# output: progamin

# %% [raw]
# Exercise 31: Find Substring
# Check whether one string exists inside another.

# %% [raw]
# Exercise 32: String Compression
# Convert:
#
# aaabbccccd
# into:
# a3b2c4d1

# %% [raw]
# Exercise 33: Reverse Each Word
# Example:
#
# input: python is fun
# output: nohtyp si nuf

# %% [raw]
# Exercise 34: Count Digits, Alphabets, Special Characters
# Input a mixed string and count each type.

# %% [raw]
# Exercise 35: List Input
# Take 5 numbers into a list and print:
#
# sum
# max
# min
# average

# %% [raw]
# Exercise 36: Separate Even and Odd
# From a list of numbers, create:
#
# even list
# odd list

# %% [raw]
# Exercise 37: Remove Duplicates from List
# Input a list and remove duplicates.

# %% [raw]
# Exercise 38: Second Largest
# Find second largest number in a list.

# %% [raw]
# Exercise 39: Reverse List
# Reverse a list:
#
# using slicing
# using loop
# using built-in method

# %% [raw]
# Exercise 40: List Comprehension Practice
# Create:
#
# squares from 1 to 20
# even numbers from 1 to 50
# cubes of odd numbers from 1 to 15

# %% [raw]
# Exercise 41: Merge Two Lists
# Combine two lists and sort them.

# %% [raw]
# Exercise 42: Rotate List
# Rotate a list by k positions.

# %% [raw]
# Exercise 43: Tuple Basics
# Create a tuple and print:
#
# length
# first item
# last item
# count of a value

# %% [raw]
# Exercise 44: Convert List to Tuple
# Take list input and convert it into tuple.

# %% [raw]
# Exercise 45: Unpack Tuple
# Create a tuple with 5 elements and unpack it into 5 variables.

# %% [raw]
# Exercise 46: Set Operations
# Create two sets and perform:
#
# union
# intersection
# difference
# symmetric difference

# %% [raw]
# Exercise 47: Remove Duplicates
# Take a list and use set to remove duplicates.

# %% [raw]
# Exercise 48: Common Elements
# Find common elements between two lists using set.

# %% [raw]
# Exercise 49: Student Dictionary
# Create a dictionary with:
#
# name
# age
# marks
# Print keys and values separately.

# %% [raw]
# Exercise 50: Frequency Counter
# Count frequency of elements in a list using dictionary.

# %% [raw]
# Exercise 51: Word Frequency
# Input a sentence and count frequency of each word.

# %% [raw]
# Exercise 52: Merge Dictionaries
# Merge two dictionaries into one.

# %% [raw]
# Exercise 53: Highest Value
# Find the key having highest value in a dictionary.

# %% [raw]
# Exercise 54: Invert Dictionary
# Convert:
#
# {"a": 1, "b": 2}
# to
# {1: "a", 2: "b"}

# %% [raw]
# Exercise 55: Range Practice
# Use range() to print:
#
# 1 to 10
# even numbers from 2 to 20
# numbers from 20 to 1

# %% [raw]
# Exercise 56: Sum with Range
# Find sum of numbers from 1 to n.

# %% [raw]
# Exercise 57: Built-ins Demo
# Use print(), len(), id(), max(), min() on different values.

# %% [raw]
# Exercise 58: Math Module Basics
# Use:
#
# math.sqrt()
# math.factorial()
# math.ceil()
# math.floor()
# math.pi

# %% [raw]
# Exercise 59: Circle Calculator
# Input radius and use math.pi to calculate:
#
# area
# circumference

# %% [raw]
# Exercise 60: Distance Formula
# Given two points (x1, y1) and (x2, y2), calculate distance using math functions.

# %% [raw]
# Exercise 61: Compound Interest
# Use formula and math operations to compute compound interest.

# %% [raw]
# Exercise 62: Import Styles
# Write 3 small programs using:
#
# import math
# from math import sqrt
# import math as m

# %% [raw]
# Exercise 63: Random Module
# Use random module to:
#
# generate a random integer
# pick a random item from a list

# %% [raw]
# Exercise 64: Custom Module
# Create your own module with functions:
#
# add
# subtract
# multiply
# Then import and use them in another file.

# %% [raw]
# Exercise 65: Simple Function
# Create a function to add two numbers.

# %% [raw]
# Exercise 66: Parameter vs Argument
# Write a function with 3 parameters and call it with different arguments.

# %% [raw]
# Exercise 67: Default Parameter
# Create a function:
#
# greet(name="Guest")

# %% [raw]
# Exercise 68: Keyword Arguments
# Call a function using keyword arguments.

# %% [raw]
# Exercise 69: Return Multiple Values
# Return sum and product of two numbers.

# %% [raw]
# Exercise 70: Variable Length Arguments
# Write a function that accepts many numbers and returns their sum.

# %% [raw]
# Exercise 71: Loop to List Comprehension
# Convert normal loop code into list comprehension.

# %% [raw]
# Exercise 72: If-Else Short Form
# Rewrite simple if-else using ternary expression.

# %% [raw]
# Exercise 73: Use Built-ins Instead of Loops
# Find:
#
# max
# min
# sum
# using built-in functions instead of manual looping.

# %% [raw]
# Exercise 74: Remove Repeated Code
# If same code is repeated many times, convert it into a function.

# %% [raw]
# Exercise 75: Efficient Membership Check
# Compare checking membership in:
#
# list
# set

# %% [raw]
# Exercise 76: Refactor Program
# Take an old long program and shorten it while keeping output same.

# %% [raw]
# Exercise 77: Print Arguments
# Write a program to print all command-line arguments.

# %% [raw]
# Exercise 78: Sum from CLI
# Take 2 or 3 numbers from sys.argv and print their sum.
#
# Example:
# python app.py 10 20 30

# %% [raw]
# Exercise 79: Name and Age from CLI
# Accept name and age from command line and print formatted output.

# %% [raw]
# Exercise 80: Calculator Using CLI
# Take:
#
# number1
# operator
# number2
# from sys.argv and perform operation.
# Example:
# python calc.py 10 + 5

# %% [raw]
# Exercise 81: File Name via CLI
# Take a filename from sys.argv and print it.

# %% [raw]
# Exercise 82: Validate Arguments
# If user gives fewer arguments, print usage message.

# %% [raw]
# Exercise 83: Simple Calculator
# Make a calculator using:
#
# input
# operators
# conditions

# %% [raw]
# Exercise 84: Mini Student Report
# Take student details and marks, then print:
#
# total
# average
# grade

# %% [raw]
# Exercise 85: ATM Simulation
# User enters balance and withdrawal amount. Check:
#
# enough balance or not
# update final balance

# %% [raw]
# Exercise 86: Number Guessing Mini Version
# Store a fixed secret number and ask user to guess.

# %% [raw]
# Exercise 87: Shopping Bill
# Take item name, quantity, price, and print final bill.

# %% [raw]
# Exercise 88: Password Checker
# Check whether password:
#
# has min length
# contains digit
# contains uppercase
# contains lowercase

# %% [raw]
# Exercise 89: Email Validator Basic
# Check if email contains:
#
# @
# .
# valid positions

# %% [raw]
# Exercise 90: Simple Menu Program
# Show menu:
#
# Add
# Subtract
# Multiply
# Exit

# %% [raw]
# Exercise 91: Marks Analyzer
# Input marks list and print:
#
# highest
# lowest
# average
# pass/fail count

# %% [raw]
# Exercise 92: Employee Salary Slip
# Input employee name, basic salary, HRA, DA, deduction and print net salary.

# %% [raw]
# Exercise 93: Anagram Check
# Check whether two strings are anagrams.

# %% [raw]
# Exercise 94: Prime Number Check
# Check if a number is prime.

# %% [raw]
# Exercise 95: List of Primes
# Print all prime numbers in a range.

# %% [raw]
# Exercise 96: Fibonacci Series
# Print first n terms.

# %% [raw]
# Exercise 97: Armstrong Number
# Check whether a number is Armstrong.

# %% [raw]
# Exercise 98: Perfect Number
# Check whether a number is perfect.

# %% [raw]
# Exercise 99: Matrix Addition
# Add two 2D lists.

# %% [raw]
# Exercise 100: Contact Book
# Create a small contact book using dictionary with options:
#
# add contact
# search contact
# delete contact
# display all

# %% [raw]
# ###   Mini Revision Tasks    ###
# These are quick daily drills.
#
# Convert decimal to binary, octal, hex
# Reverse a string
# Count vowels in a sentence
# Find largest in a list
# Remove duplicates from list
# Print common values of two sets
# Create dictionary word count
# Use math.sqrt() in a program
# Take 2 numbers from sys.argv and multiply
# Format output using format() and f-string
