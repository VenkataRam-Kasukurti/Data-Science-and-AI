# %% [markdown]
# Phase 1: Days 1–10
# Day 1: Calculator Console App
# Goal
# Build a calculator using:
#
# input()
# arithmetic operators
# if-elif-else
# Features
# take 2 numbers
# take operator
# perform calculation
# handle invalid operator
# Concepts used
# variables
# type casting
# operators
# input/output
# Bonus
# add %, //, **
#
#
#
# Day 2: Age Calculator
# Goal
# Calculate a user's age from birth year.
#
# Features
# input birth year
# calculate age
# classify:
# child
# adult
# senior
# Concepts used
# input
# arithmetic
# conditional statements
# Bonus
# also print age after 10 years
#
#
# Day 3: Number Analyzer
# Goal
# Analyze one number in multiple ways.
#
# Features
# Check whether the number is:
#
# even or odd
# positive, negative, or zero
# divisible by 3
# divisible by 5
# Concepts used
# %
# conditions
# logical operators
# Bonus
# also check if number is in range 1 to 100
# Day 4: Temperature Converter
# Goal
# Convert temperature between Celsius and Fahrenheit.
#
# Features
# user chooses conversion type
# input temperature
# print converted value
# Concepts used
# formulas
# menu logic
# numeric input
# Bonus
# repeat until user exits
# Day 5: Student Result Generator
# Goal
# Take student marks and print result.
#
# Features
# name
# marks in 5 subjects
# total
# average
# grade
# Concepts used
# variables
# arithmetic
# formatted output
# Bonus
# print pass/fail based on minimum subject marks
# Day 6: Salary Slip Generator
# Goal
# Generate salary slip from salary components.
#
# Features
# employee name
# basic salary
# HRA
# DA
# deduction
# gross salary
# net salary
# Concepts used
# arithmetic
# formatting
# real-world calculations
# Bonus
# percentage-based HRA and DA
# Day 7: Shopping Bill Generator
# Goal
# Create a simple item billing system.
#
# Features
# item name
# quantity
# price
# subtotal
# tax
# final amount
# Concepts used
# multiplication
# float input
# formatted printing
# Bonus
# multiple items using list or loop
# Day 8: BMI Calculator
# Goal
# Calculate BMI and category.
#
# Features
# input height
# input weight
# calculate BMI
# print category
# Concepts used
# formulas
# conditionals
# Bonus
# support height in cm and meters
# Day 9: Word and Character Counter
# Goal
# Analyze a sentence.
#
# Features
# total characters
# total words
# spaces
# vowels
# consonants
# Concepts used
# strings
# loops
# string methods
# Bonus
# count digits and special characters
# Day 10: Palindrome Checker
# Goal
# Check whether a word or sentence is palindrome.
#
# Features
# input string
# normalize string if needed
# compare reverse
# Concepts used
# slicing
# strings
# conditions
# Bonus
# ignore spaces and case
# Phase 2: Days 11–20
# Day 11: Vowel and Character Frequency Analyzer
# Goal
# Count each character and vowels in text.
#
# Features
# count vowels
# count each character frequency
# display neatly
# Concepts used
# dictionary
# strings
# loops
# Bonus
# ignore spaces during frequency count
# Day 12: To-Do List Manager
# Goal
# Create a simple task manager.
#
# Features
# add task
# show tasks
# remove task
# mark as done
# Concepts used
# list
# menu
# loops
# Bonus
# store task status separately
# Day 13: Contact Book
# Goal
# Store and manage contacts.
#
# Features
# add contact
# search contact
# update contact
# delete contact
# display all contacts
# Concepts used
# dictionary
# menu-driven logic
# Bonus
# validate duplicate contact names
# Day 14: Expense Tracker
# Goal
# Track expenses by category.
#
# Features
# add expense
# category name
# total expense
# category-wise summary
# Concepts used
# dictionary
# loops
# numeric totals
# Bonus
# show highest expense category
# Day 15: Attendance Manager
# Goal
# Manage present/absent data of students.
#
# Features
# student names
# attendance status
# count present
# count absent
# Concepts used
# dictionary or list
# conditionals
# loops
# Bonus
# print absent students only
# Day 16: Marks Analyzer
# Goal
# Analyze marks stored in a list.
#
# Features
# highest mark
# lowest mark
# average
# pass count
# fail count
# Concepts used
# list
# built-in functions
# loops
# Bonus
# display topper index or name
# Day 17: Number Base Converter
# Goal
# Convert decimal to:
#
# binary
# octal
# hexadecimal
# Features
# input decimal number
# display all conversions
# Concepts used
# built-ins:
# bin()
# oct()
# hex()
# Bonus
# reverse conversion too
# Day 18: Bitwise Operation Tool
# Goal
# Practice all bitwise operators.
#
# Features
# Take two numbers and display:
#
# &
# |
# ^
# ~
# <<
# >>
# Concepts used
# bitwise operators
# binary understanding
# Bonus
# also print binary form before and after
# Day 19: Password Strength Checker
# Goal
# Check password quality.
#
# Features
# Verify:
#
# minimum length
# uppercase
# lowercase
# digit
# special character
# Concepts used
# strings
# loops
# boolean flags
# Bonus
# score password strength out of 5
# Day 20: Email Validator
# Goal
# Validate an email with basic rules.
#
# Features
# Check:
#
# contains @
# contains .
# valid position
# no spaces
# Concepts used
# string methods
# conditions
# Bonus
# split username and domain
# Phase 3: Days 21–30
# Day 21: CLI Calculator
# Goal
# Create a calculator using sys.argv.
#
# Features
# pass number1
# operator
# number2
# print result
# Concepts used
# sys.argv
# type casting
# CLI execution
# Bonus
# validate missing arguments
# Day 22: CLI Student Report
# Goal
# Generate student report from command-line values.
#
# Features
# name from CLI
# marks from CLI
# total
# average
# grade
# Concepts used
# sys.argv
# list of arguments
# calculations
# Bonus
# support variable number of marks
# Day 23: Custom Utility Module
# Goal
# Create your own Python module.
#
# Features
# Create functions for:
#
# add
# subtract
# multiply
# divide
# Import them into another file.
#
# Concepts used
# modules
# import
# from ... import
# as
# Bonus
# create string utility functions too
# Day 24: Inventory Management Tool
# Goal
# Track products in inventory.
#
# Features
# add product
# update quantity
# remove product
# display inventory
# Concepts used
# dictionary
# menu-driven app
# functions
# Bonus
# store quantity and price together
# Day 25: ATM Simulation
# Goal
# Simulate basic ATM operations.
#
# Features
# check balance
# deposit
# withdraw
# mini statement
# Concepts used
# conditions
# loops
# arithmetic
# functions
# Bonus
# reject invalid withdrawals
# Day 26: Voting Result Counter
# Goal
# Create a simple voting system.
#
# Features
# candidates list
# cast vote
# count votes
# display winner
# Concepts used
# dictionary
# counting
# loops
# Bonus
# handle tie situation
# Day 27: Library Book Tracker
# Goal
# Manage books and availability.
#
# Features
# add book
# issue book
# return book
# display status
# Concepts used
# dictionary
# menu
# stock tracking
# Bonus
# show only available books
# Day 28: Quiz Application
# Goal
# Build a basic quiz program.
#
# Features
# ask multiple questions
# check answers
# count score
# show final result
# Concepts used
# lists
# dictionaries
# conditions
# loops
# Bonus
# randomize questions using random
# Day 29: Multi-Utility Console App
# Goal
# Combine small tools into one menu app.
#
# Features
# Menu options:
#
# calculator
# string analyzer
# number converter
# list analyzer
# Concepts used
# functions
# menu-driven design
# modular structure
# Bonus
# split each tool into separate functions
# Day 30: Final Combined Project
# Goal
# Build one polished project from all your learning.
#
# Choose one
# Contact Book Pro
# Expense Tracker Pro
# Student Record System
# Employee Management System
# Multi-Utility Python App
# Requirements
# use functions
# clean menu
# proper formatting
# input validation
# reusable logic
# Bonus
# use custom module
# support CLI mode for some features
#
#
#
# ####   Optional Stretch Goals     ####
# If you finish early on any day, add one of these:
#
# use format() and f-strings
# add error handling with try-except
# support repeated menu loop
# optimize using built-ins
# split code into functions
# create custom module
# add sys.argv support
