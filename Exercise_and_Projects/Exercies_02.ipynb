# %% [markdown]
# # 100 Python Exercises

# %% [raw]
# 1. Variable creation
# Create variables for name, age, salary, and city. Print each with its type.

# %% [raw]
# 2. Multiple assignment
# Assign three values to three variables in one line and print them.

# %% [raw]
# 3. Same value assignment
# Assign the same value to three variables and print them.

# %% [raw]
# 4. Swap values
# Swap two variables using a third variable.

# %% [raw]
# 5. Swap without third variable
# Swap two variables without using a third variable.

# %% [raw]
# 6. Input as string
# Take user name as input and print a welcome message.

# %% [raw]
# 7. Input as integer
# Take age as input and print age after 10 years.

# %% [raw]
# 8. Input as float
# Take product price and print price after adding 18% tax.

# %% [raw]
# 9. Type casting string to int
# Take a numeric string and convert it into integer.

# %% [raw]
# 10. Type casting int to float and string
# Convert an integer into float and string and print all.

# %% [raw]
# 11. Arithmetic operations
# Take two numbers and print all arithmetic results.

# %% [raw]
# 12. Floor division and modulus
# Input two integers and print quotient and remainder.

# %% [raw]
# 13. Exponent operator
# Find power of a number using **.

# %% [raw]
# 14. Assignment operators
# Use +=, -=, *=, /= on a variable and print after each step.

# %% [raw]
# 15. Comparison operators
# Compare two numbers using all relational operators.

# %% [raw]
# 16. Logical and
# Check whether a person is eligible to vote and has ID proof.

# %% [raw]
# 17. Logical or
# Check whether a student passed if marks in theory or practical are above threshold.

# %% [raw]
# 18. Logical not
# Take a boolean value and print its opposite.

# %% [raw]
# 19. Unary minus
# Input a number and print its negative form.

# %% [raw]
# 20. Mixed operator expression
# Evaluate an expression with arithmetic and relational operators.

# %% [raw]
# 21. Even or odd
# Check whether a number is even or odd.

# %% [raw]
# 22. Positive, negative, or zero
# Determine the category of a number.

# %% [raw]
# 23. Largest of two
# Find the greater of two numbers.

# %% [raw]
# 24. Largest of three
# Find the largest among three numbers.

# %% [raw]
# 25. Smallest of three
# Find the smallest among three numbers.

# %% [raw]
# 26. Divisible check
# Check whether a number is divisible by both 3 and 5.

# %% [raw]
# 27. Leap year
# Check whether a year is leap year.

# %% [raw]
# 28. Reverse a number
# Reverse digits of an integer.

# %% [raw]
# 29. Sum of digits
# Find sum of digits of a number.

# %% [raw]
# 30. Product of digits
# Find product of digits of a number.

# %% [raw]
# 31. Decimal to binary
# Convert decimal number to binary.

# %% [raw]
# 32. Decimal to octal
# Convert decimal number to octal.

# %% [raw]
# 33. Decimal to hexadecimal
# Convert decimal number to hexadecimal.

# %% [raw]
# 34. Binary to decimal
# Take a binary string and convert to decimal.

# %% [raw]
# 35. Bitwise AND
# Perform & operation on two numbers.

# %% [raw]
# 36. Bitwise OR
# Perform | operation on two numbers.

# %% [raw]
# 37. Bitwise XOR
# Perform ^ operation on two numbers.

# %% [raw]
# 38. Bitwise complement
# Find bitwise complement of a number.

# %% [raw]
# 39. Left shift
# Shift a number left by 1, 2, and 3 positions.

# %% [raw]
# 40. Right shift
# Shift a number right by 1, 2, and 3 positions.

# %% [raw]
# 41. String length
# Take a string and print its length.

# %% [raw]
# 42. First and last character
# Print first and last character of a string.

# %% [raw]
# 43. String slicing
# Print first 3 characters, last 3 characters, and middle part.

# %% [raw]
# 44. Reverse string
# Reverse a string using slicing.

# %% [raw]
# 45. Palindrome string
# Check whether a string is palindrome.

# %% [raw]
# 46. Count vowels
# Count vowels in a string.

# %% [raw]
# 47. Count consonants
# Count consonants in a string.

# %% [raw]
# 48. Count spaces
# Count number of spaces in a sentence.

# %% [raw]
# 49. Character frequency
# Count frequency of each character.

# %% [raw]
# 50. Replace substring
# Replace one word with another in a sentence.

# %% [raw]
# 51. Remove spaces
# Remove all spaces from a string.

# %% [raw]
# 52. Upper/lower/title
# Convert a string into upper, lower, and title case.

# %% [raw]
# 53. Count words
# Count total words in a sentence.

# %% [raw]
# 54. Find substring
# Check whether a substring exists in a string.

# %% [raw]
# 55. Remove duplicate characters
# Remove repeated characters from a string.

# %% [raw]
# 56. Create a list
# Create a list of 5 numbers and print it.

# %% [raw]
# 57. Sum of list
# Find sum of all elements.

# %% [raw]
# 58. Max and min
# Find largest and smallest element in a list.

# %% [raw]
# 59. Average of list
# Find average of all elements.

# %% [raw]
# 60. Even numbers from list
# Extract even numbers from a list.

# %% [raw]
# 61. Odd numbers from list
# Extract odd numbers from a list.

# %% [raw]
# 62. Reverse a list
# Reverse a list using slicing.

# %% [raw]
# 63. Sort ascending
# Sort a list in ascending order.

# %% [raw]
# 64. Sort descending
# Sort a list in descending order

# %% [raw]
# 65. Remove duplicates
# Remove duplicate elements from a list.

# %% [raw]
# 66. Second largest
# Find second largest element in a list.

# %% [raw]
# 67. Merge two lists
# Combine two lists into one.

# %% [raw]
# 68. Common elements
# Find common elements of two lists.

# %% [raw]
# 69. List comprehension squares
# Create list of squares from 1 to 20.

# %% [raw]
# 70. List comprehension evens
# Create list of even numbers from 1 to 50.

# %% [raw]
# 71. Tuple basics
# Create a tuple and print its length.

# %% [raw]
# 72. Tuple unpacking
# Unpack tuple values into variables.

# %% [raw]
# 73. Convert list to tuple
# Convert a list into tuple.

# %% [raw]
# 74. Set basics
# Create a set and print unique elements

# %% [raw]
# 75. Set union
# Find union of two sets.

# %% [raw]
# 76. Set intersection
# Find intersection of two sets.

# %% [raw]
# 77. Set difference
# Find difference of two sets.

# %% [raw]
# 78. Dictionary creation
# Create a dictionary with student details.

# %% [raw]
# 79. Dictionary keys and values
# Print keys and values separately

# %% [raw]
# 80. Update dictionary
# Add a new key-value pair to dictionary.

# %% [raw]
# 81. Frequency using dictionary
# Count frequency of list elements using dictionary.

# %% [raw]
# 82. Word frequency
# Count frequency of words in a sentence.

# %% [raw]
# 83. Range output
# Print numbers from 1 to 20 using range().

# %% [raw]
# 84. Reverse range
# Print numbers from 20 to 1 using range().

# %% [raw]
# 85. Sum using range
# Find sum of numbers from 1 to n.

# %% [raw]
# 86. len() practice
# Use len() on string, list, tuple, and dictionary.

# %% [raw]
# 87. max() and min()
# Find max and min from numbers and list.

# %% [raw]
# 88. id() practice
# Print memory identity of different objects.

# %% [raw]
# 89. abs() practice
# Print absolute value of negative numbers.

# %% [raw]
# 90. round() practice
# Round float values to 1, 2, and 3 decimal places.

# %% [raw]
# 91. math.sqrt()
# Find square root of a number.

# %% [raw]
# 92. math.factorial()
# Find factorial of a number.

# %% [raw]
# 93. math.ceil() and math.floor()
# Apply both on decimal values.

# %% [raw]
# 94. Circle area
# Use math.pi to find area of a circle.

# %% [raw]
# 95. Hypotenuse
# Use math formula to calculate hypotenuse.

# %% [raw]
# 96. Function with parameters
# Write a function that adds two numbers.

# %% [raw]
# 97. Default parameter
# Write a greeting function with default name.

# %% [raw]
# 98. Variable-length arguments
# Write a function that accepts multiple numbers and returns sum.

# %% [raw]
# 99. Custom module
# Create a module with 3 arithmetic functions and import it.

# %% [raw]
# 100. sys.argv program
# Take two numbers from command line and print their sum.

# %% [raw]
# ###  Variables and Data Types  ###
# Create variables of type int, float, str, bool, complex
# Print type of each
# Convert integer to float
# Convert float to int
# Convert number to string
# Convert string digit to integer
# Check datatype before and after casting
# Assign multiple variables in one line
# Assign same value to multiple variables
# Print id() of two equal integers and compare

# %% [raw]
# ###  Input and Output  ###
# Take user name and greet them
# Take 2 integers and print sum
# Take 2 floats and print product
# Take a sentence and print number of words
# Take input and convert into integer
# Take input and convert into float
# Take arithmetic expression using eval()
# Print output using comma-separated print
# Print output using format()

# %% [raw]
# ####  Operators  ####
# Add, subtract, multiply, divide two numbers
# Find quotient and remainder
# Use exponent operator
# Apply assignment operators step by step
# Compare two numbers with all relational operators
# Check if both conditions are true using and
# Check if one condition is true using or
# Reverse boolean using not
# Use unary plus and unary minus
# Solve a mixed arithmetic expression

# %% [raw]
# ####  Bitwise Operators  ####
# Perform &, |, ^ on two integers
# Find complement of a number
# Left-shift a number by 2
# Right-shift a number by 3
# Check odd/even using bitwise operator
# Display binary representation using bin()
# Convert decimal into binary, octal, hex
# Toggle a bit at given position
# Set a bit at given position
# Clear a bit at given position

# %% [raw]
# ####    Strings    ####
# Print first and last character
# Reverse string
# Check palindrome
# Count vowels
# Count consonants
# Count uppercase and lowercase letters
# Count digits and special characters
# Remove spaces
# Replace a word in sentence
# Find substring
# Split sentence into words
# Join list of words into string
# Remove duplicate characters
# Sort characters in a string
# Compress repeated characters

# %% [raw]
# ####    Lists    ####
# Input 5 elements into a list
# Find sum, average, max, min
# Append and insert elements
# Remove an element by value
# Remove an element by index
# Reverse list
# Sort list ascending and descending
# Find second largest element
# Separate even and odd numbers
# Merge two lists
# Find common elements
# Remove duplicates
# Rotate list by k positions
# Create list of squares using list comprehension
# Create filtered list using condition

# %% [raw]
# ####    Tuples    ####
# Create tuple with 5 elements
# Access tuple elements
# Slice a tuple
# Count frequency of a value in tuple
# Find index of an item
# Convert list to tuple
# Convert tuple to list
# Unpack tuple into variables
# Create single-element tuple
# Concatenate two tuples

# %% [raw]
# ####    Sets    ####
# Create set from list
# Add element to set
# Remove element from set
# Perform union
# Perform intersection
# Perform difference
# Perform symmetric difference
# Check subset
# Check superset
# Remove duplicates from list using set

# %% [raw]
# ####    Dictionaries    ####
# Create student dictionary
# Add new key-value pair
# Update existing value
# Delete a key
# Print all keys
# Print all values
# Loop through dictionary
# Count frequency of list elements
# Count frequency of words in sentence
# Merge two dictionaries
# Find key with maximum value
# Invert dictionary

# %% [raw]
# ####    Range    ####
# Print numbers from 1 to 10
# Print even numbers from 2 to 20
# Print odd numbers from 1 to 19
# Print numbers in reverse order
# Sum values in range
# Multiply values in range
# Create list from range
# Print table of a number using range
# Print squares using range
# Use step value in range

# %% [raw]
# ####    Built-in Functions    ####
# Practice print()
# Practice len()
# Practice id()
# Practice type()
# Practice max()
# Practice min()
# Practice sum()
# Practice abs()
# Practice round()
# Practice sorted()

# %% [raw]
# ####    Math Module    ####
# Square root of a number
# Factorial of a number
# Floor and ceil of decimals
# Use math.pi
# Area of circle
# Circumference of circle
# Power using math module
# Distance between two points
# Trigonometric function practice
# Logarithm practice

# %% [raw]
# ####    Import, From, As    ####
# Use import math
# Use from math import sqrt
# Use import math as m
# Import only pi and compute area
# Import multiple items from module
# Create custom module
# Import custom module in another file
# Alias custom module
# Use dir() to inspect module
# Compare full import vs selective import

# %% [raw]
# ####  Functions and Parameters   ####
# Function without parameters
# Function with 2 parameters
# Function with return value
# Function with default parameter
# Function with keyword arguments
# Function with variable-length arguments
# Function returning multiple values
# Function calling another function
# Difference between parameter and argument in examples
# Create reusable calculator functions

# %% [raw]
# ####    input() and eval()    ####
# Take integer input
# Take float input
# Take multiple numbers in one line
# Take expression using eval()
# Build simple calculator using input()
# Read sentence and count words
# Take list input manually
# Take comma-separated values and convert to list
# Take two values and swap them
# Read dimensions and calculate area

# %% [raw]
# ####    CLI and sys.argv    ####
# Print all CLI arguments
# Print number of CLI arguments
# Take name from CLI
# Take name and age from CLI
# Take two numbers from CLI and add
# Multiply CLI arguments
# Validate number of arguments
# Build CLI calculator
# Read filename from CLI
# Print usage message when arguments are missing
