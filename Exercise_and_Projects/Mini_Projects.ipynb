# %% [markdown]
# # Mini Projects

# %% [raw]
# 1. Simple calculator
# Input two numbers and operator
# Perform operation
# Handle invalid operator

# %% [raw]
# 2. Age calculator
# Input birth year
# Print current age

# %% [raw]
# 3. Number analyzer
# Input a number
# Print whether it is even/odd, positive/negative, divisible by 3 or 5

# %% [raw]
# 4. Temperature converter
# Celsius to Fahrenheit
# Fahrenheit to Celsius

# %% [raw]
# 5. BMI calculator
# Input height and weight
# Calculate BMI
# Print category

# %% [raw]
# 6. Student marks report
# Input marks of 5 subjects
# Print total, average, grade

# %% [raw]
# 7. Shopping bill generator
# Item name, quantity, price
# Print subtotal, tax, final amount

# %% [raw]
# 8. EMI / loan simple calculator
# Principal, rate, time
# Print simple interest or EMI approximation

# %% [raw]
# 9. Unit converter
# Length, weight, temperature conversions

# %% [raw]
# 10. Table generator
# Input a number
# Print multiplication table

# %% [raw]
# 11. Password strength checker
# Check length
# Uppercase
# Lowercase
# Digit
# Special character

# %% [raw]
# 12. Palindrome checker tool
# Check if input word/sentence is palindrome

# %% [raw]
# 13. Word counter
# Count words, characters, spaces, vowels

# %% [raw]
# 14. Email validator basic
# Check '@'','' .', invalid positions

# %% [raw]
# 15. Text formatter
# Convert text into upper, lower, title, reversed

# %% [raw]
# 16. Character frequency analyzer
# Count each character in a string

# %% [raw]
# 17. Anagram checker
# Check whether two strings are anagrams

# %% [raw]
# 18. String compression tool
# Compress repeated letters

# %% [raw]
# 19. Username generator
# Generate username from first and last name

# %% [raw]
# 20. Sentence statistics tool
# Count words, longest word, shortest word

# %% [raw]
# 21. Contact book
# Add contact
# Search contact
# Delete contact
# Display all

# %% [raw]
# 22. To-do list manager
# Add task
# Remove task
# View tasks
# Mark complete

# %% [raw]
# 23. Student database
# Store student names and marks in dictionary
# Search and update records

# %% [raw]
# 24. Inventory tracker
# Item name, quantity, price
# Add/update/remove item

# %% [raw]
# 25. Expense tracker
# Add daily expenses
# Print total and category summary

# %% [raw]
# 26. Attendance manager
# Track present/absent students

# %% [raw]
# 27. Frequency analyzer
# Take list of items and count occurrence

# %% [raw]
# 28. Unique visitors tracker
# Use set to store unique usernames

# %% [raw]
# 29. Voting result counter
# Count votes using dictionary

# %% [raw]
# 30. Library book tracker
# Add books
# Borrow book
# Return book
# Show availability

# %% [raw]
# 31. Prime checker tool
# Check prime number

# %% [raw]
# 32. Prime range generator
# Print primes in a given range

# %% [raw]
# 33. Fibonacci generator
# Print first n Fibonacci terms

# %% [raw]
# 34. Armstrong number checker
# Check Armstrong number

# %% [raw]
# 35. Perfect number checker
# Check perfect number

# %% [raw]
# 36. Factorial calculator
# Use function and math.factorial()

# %% [raw]
# 37. GCD and LCM calculator
# Input two numbers
# Print GCD and LCM

# %% [raw]
# 38. Number base converter
# Decimal to binary/octal/hex

# %% [raw]
# 39. Bitwise visualizer
# Show binary representation before and after bitwise operation

# %% [raw]
# 40. Equation evaluator
# Evaluate user-entered mathematical expression carefully

# %% [raw]
# 41. CLI calculator
# Take values from sys.argv

# %% [raw]
# 42. CLI student result tool
# Name and marks from command line
# Print report

# %% [raw]
# 43. Custom math utility module
# Create own module for arithmetic and import it

# %% [raw]
# 44. CLI file info mock tool
# Pass filename as argument and display mock metadata

# %% [raw]
# 45. Greeting app using function module
# Store greeting functions in one file, call from another

# %% [raw]
# 46. Unit conversion module
# Build reusable conversion functions

# %% [raw]
# 47. Employee salary slip generator
# Use functions for HRA, DA, tax, net salary

# %% [raw]
# 48. Marks processing package
# Create package with subject and grade helpers

# %% [raw]
# 49. Command-line login simulator
# Take username/password via CLI and validate

# %% [raw]
# 50. Multi-function utility app
# Menu-based app with options for calculator, converter, string tools
