# %% [markdown]
# # 50 Mini Projects by Difficulty Level

# %% [markdown]
# # Beginner Mini Projects

# %% [raw]
# 1. Basic Calculator
# Build a calculator that takes two numbers and an operator from the user and prints the result.

# %% [raw]
# 2. Age Finder
# Input birth year and current year, then calculate age.

# %% [raw]
# 3. Even/Odd Checker
# Input a number and determine whether it is even or odd.

# %% [raw]
# 4. Positive/Negative/Zero Checker
# Read a number and classify it as positive, negative, or zero.

# %% [raw]
# 5. Largest of Three Numbers
# Take three numbers and print the largest one.

# %% [raw]
# 6. Simple Interest Calculator
# Input principal, rate, and time, then calculate simple interest.

# %% [raw]
# 7. Temperature Converter
# Convert temperature between Celsius and Fahrenheit.

# %% [raw]
# 8. EMI / loan simple calculator
# Principal, rate, time
# Print simple interest or EMI approximation

# %% [raw]
# 9. Unit converter
# Length, weight, temperature conversions

# %% [raw]
# 10. Table generator
# Input a number
# Print multiplication table

# %% [markdown]
# # String-Based Mini Projects

# %% [raw]
# 11. Password strength checker
# Check length
# Uppercase
# Lowercase
# Digit
# Special character

# %% [raw]
# 12. Palindrome checker tool
# Check if input word/sentence is palindrome

# %% [raw]
# 13. Word counter
# Count words, characters, spaces, vowels

# %% [raw]
# 14. Email validator basic
# Check @, ., invalid positions

# %% [raw]
# 15. Text formatter
# Convert text into upper, lower, title, reversed

# %% [raw]
# 16. Character frequency analyzer
# Count each character in a string

# %% [raw]
# 17. Anagram checker
# Check whether two strings are anagrams

# %% [raw]
# 18. String compression tool
# Compress repeated letters

# %% [raw]
# 19. Username generator
# Generate username from first and last name

# %% [raw]
# 20. Sentence statistics tool
# Count words, longest word, shortest word

# %% [markdown]
# # List / Set / Dictionary Mini Projects

# %% [raw]
# 21. Contact book
# Add contact
# Search contact
# Delete contact
# Display all

# %% [raw]
# 22. To-do list manager
# Add task
# Remove task
# View tasks
# Mark complete

# %% [raw]
# 23. Student database
# Store student names and marks in dictionary
# Search and update records

# %% [raw]
# 24. Inventory tracker
# Item name, quantity, price
# Add/update/remove item

# %% [raw]
# 25. Expense tracker
# Add daily expenses
# Print total and category summary

# %% [raw]
# 26. Attendance manager
# Track present/absent students

# %% [raw]
# 27. Frequency analyzer
# Take list of items and count occurrence

# %% [raw]
# 28. Unique visitors tracker
# Use set to store unique usernames

# %% [raw]
# 29. Voting result counter
# Count votes using dictionary

# %% [raw]
# 30. Library book tracker
# Add books
# Borrow book
# Return book
# Show availability

# %% [markdown]
# # Math / Logic Mini Projects

# %% [raw]
# 31. Prime checker tool
# Check prime number

# %% [raw]
# 32. Prime range generator
# Print primes in a given range

# %% [raw]
# 33. Fibonacci generator
# Print first n Fibonacci terms

# %% [raw]
# 34. Armstrong number checker
# Check Armstrong number

# %% [raw]
# 35. Perfect number checker
# Check perfect number

# %% [raw]
# 36. Factorial calculator
# Use function and math.factorial()

# %% [raw]
# 37. GCD and LCM calculator
# Input two numbers
# Print GCD and LCM

# %% [raw]
# 38. Number base converter
# Decimal to binary/octal/hex

# %% [raw]
# 39. Bitwise visualizer
# Show binary representation before and after bitwise operation

# %% [raw]
# 40. Equation evaluator
# Evaluate user-entered mathematical expression carefully

# %% [markdown]
# # Function / Module / CLI Mini Projects

# %% [raw]
# 41. CLI calculator
# Take values from sys.argv

# %% [raw]
# 42. CLI student result tool
# Name and marks from command line
# Print report

# %% [raw]
# 43. Custom math utility module
# Create own module for arithmetic and import it

# %% [raw]
# 44. CLI file info mock tool
# Pass filename as argument and display mock metadata

# %% [raw]
# 45. Greeting app using function module
# Store greeting functions in one file, call from another

# %% [raw]
# 46. Unit conversion module
# Build reusable conversion functions

# %% [raw]
# 47. Employee salary slip generator
# Use functions for HRA, DA, tax, net salary

# %% [raw]
# 48. Marks processing package
# Create package with subject and grade helpers

# %% [raw]
# 49. Command-line login simulator
# Take username/password via CLI and validate

# %% [raw]
# 50. Multi-function utility app
# Menu-based app with options for calculator, converter, string tools

# %% [raw]
# Beginner Mini Projects
# 1. Basic Calculator
# Build a calculator that takes two numbers and an operator from the user and prints the result.
#
# 2. Age Finder
# Input birth year and current year, then calculate age.
#
# 3. Even/Odd Checker
# Input a number and determine whether it is even or odd.
#
# 4. Positive/Negative/Zero Checker
# Read a number and classify it as positive, negative, or zero.
#
# 5. Largest of Three Numbers
# Take three numbers and print the largest one.
#
# 6. Simple Interest Calculator
# Input principal, rate, and time, then calculate simple interest.
#
# 7. Temperature Converter
# Convert temperature between Celsius and Fahrenheit.
#
# 8. Area Calculator
# Compute area of square, rectangle, and circle based on user choice.
#
# 9. Multiplication Table Generator
# Input a number and print its multiplication table.
#
# 10. Sum of Digits
# Take an integer and calculate the sum of its digits.
#
# 11. Reverse a Number
# Input a number and print its reverse.
#
# 12. Leap Year Checker
# Check whether a given year is leap year.
#
# 13. Student Grade Calculator
# Input marks of multiple subjects, then calculate total, average, and grade.
#
# 14. Salary Slip Generator
# Input basic salary and calculate allowances, deductions, and net salary.
#
# 15. Shopping Bill Generator
# Take item name, quantity, and unit price, then generate final bill.
#
# 16. BMI Calculator
# Input height and weight, calculate BMI, and show category.
#
# 17. Vowel Counter
# Count number of vowels in an entered string.
#
# 18. Palindrome Checker
# Check whether a string is palindrome.
#
# 19. Word Counter
# Count total words in a sentence.
#
# 20. String Case Converter
# Convert a string to uppercase, lowercase, and title case.
#
# Intermediate Mini Projects
# 21. Password Strength Checker
# Check whether a password has minimum length, uppercase, lowercase, digit, and special character.
#
# 22. Email Validator
# Validate whether an entered email follows basic rules.
#
# 23. Number Base Converter
# Convert decimal number into binary, octal, and hexadecimal.
#
# 24. Bitwise Operation Tool
# Take two integers and show result of all bitwise operators.
#
# 25. To-Do List App
# Allow users to add, remove, and display tasks.
#
# 26. Contact Book
# Store contacts using dictionary and support add, search, delete, and display operations.
#
# 27. Expense Tracker
# Allow user to enter daily expenses and show total and category-wise summary.
#
# 28. Attendance Manager
# Store student names and attendance status and print final report.
#
# 29. Inventory Manager
# Track product name, quantity, and price using dictionary.
#
# 30. Marks Analyzer
# Input marks list and print highest, lowest, average, pass count, and fail count.
#
# 31. List Duplicate Remover
# Take a list and remove duplicates while preserving useful output.
#
# 32. Character Frequency Analyzer
# Count frequency of every character in a string.
#
# 33. Word Frequency Counter
# Count frequency of every word in a sentence or paragraph.
#
# 34. Anagram Checker
# Check whether two strings are anagrams.
#
# 35. Number Guessing Game
# Store a secret number and let user guess until correct.
#
# 36. ATM Simulation
# Simulate deposit, withdrawal, balance check, and insufficient balance handling.
#
# 37. Mini Banking App
# Support account creation, deposit, withdrawal, and mini statement.
#
# 38. Menu-Driven Calculator
# Show options repeatedly until the user chooses exit.
#
# 39. CLI Calculator
# Take values using sys.argv and perform arithmetic operations.
#
# 40. CLI Student Result Tool
# Accept student name and marks through command-line arguments and print report.
#
# Advanced Mini Projects
# 41. Library Management System
# Maintain books, issue/return functionality, and available stock report.
#
# 42. Employee Management System
# Store employee details and perform add, update, delete, and search operations.
#
# 43. Student Record System
# Manage student records with roll number, marks, and grades.
#
# 44. Quiz Application
# Ask multiple questions, store score, and display final result.
#
# 45. Custom Python Module Project
# Create your own utility module with arithmetic, string, or conversion functions and import it into another program.
#
# 46. Package-Based Utility App
# Create a package containing multiple modules such as math utilities, string tools, and validators.
#
# 47. CLI File Utility
# Pass file name from command line and show mock file info like extension, length, and filename analysis.
#
# 48. Text Analyzer Tool
# Analyze a paragraph and print number of words, lines, characters, vowels, and special characters.
#
# 49. Voting System
# Allow users to vote for candidates and display vote counts and winner.
#
# 50. Multi-Utility Console App
# Create one menu-driven console app containing calculator, converter, string tools, list tools, and dictionary tools.

# %% [raw]
# python_practice/
# ├── basics/
# ├── operators/
# ├── strings/
# ├── lists/
# ├── tuples_sets_dict/
# ├── functions/
# ├── modules/
# ├── cli/
# ├── mini_projects/
# └── tracker.md
