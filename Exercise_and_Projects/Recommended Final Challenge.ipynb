# %% [markdown]
# #####    Recommended Final Challenge     ####
# After Day 30, build 1 capstone project:
# Choose one:
#
# Student Management System
#
# Expense Tracker
#
# Inventory Manager
#
# Library System
#
# Python Multi-Tool App
#
# Make sure it includes:
#
# menu
#
# functions
#
# dictionary/list usage
#
# input validation
#
# formatted output
#
# optional CLI support
