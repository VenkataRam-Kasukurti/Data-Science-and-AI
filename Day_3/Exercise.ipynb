# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist)  # list all python keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)  # python contains 35 keywords
# Out:
# 35

# %% [markdown]
# Identifiers

# %%
1var = 10 # Identifier can't start with a digit
# Out:
#   Cell In[7], line 1
#     1var = 10 # Identifier can't start with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35 # Identifier can't use special symbols
# Out:
#   Cell In[8], line 1
#     val2@ = 35 # Identifier can't use special symbols
#           ^
# SyntaxError: invalid syntax

# %%
import = 125 # keywords can't be used as identifiers
# Out:
#   Cell In[9], line 1
#     import = 125 # keywords can't be used as identifiers
#            ^
# SyntaxError: invalid syntax

# %%
""" Corrct way of defining an identifier
(Identifiers can be a combination of letters in lowercase(a to z) or uppercase)
"""
val2 = 10

# %%
val_ = 99

# %%
# single line comment
val1 = 10

# %%
# multiple
# line
# comment
val1 = 10

# %%
'''Multiple
line
comment'''

val1 = 10

# %% [markdown]
# # Statements

# %%
p = 20
q = 20
r = q
p, type(p), hex(id(p))
# Out:
# (20, int, '0x7ffb5d23a6d8')

# %%
q, type(q), hex(id(q))
# Out:
# (20, int, '0x7ffb5d23a6d8')

# %%
r, type(r), hex(id(r))
# Out:
# (20, int, '0x7ffb5d23a6d8')

# %%
p = 20
p = p + 10
p
# Out:
# 30

# %% [markdown]
# # variable Assigment

# %%
intvar = 10
floatvar = 2.57
satvar = "python language"

print(intvar)
print(floatvar)
print(satvar)
# Out:
# 10
# 2.57
# python language

# %% [markdown]
# # Data Types

# %%
val1 = 10  # Integer data type
print(val1)
print(type(val1))  # type of object
print(sys.getsizeof(val1))  # size of integer object in bytes
# val1 is an instance of int
print(val1, " is Integer?", isinstance(val1, int))
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2 = 92.78  # Float data type
print(val2)
print(type(val2))  # type of object
print(sys.getsizeof(val2))  # size of float object in bytes
# Val2 is an instance of float
print(val2, " is float?", isinstance(val2, float))
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
val3 = 25 + 10j  # Complex data type
print(val3)
print(type(val3))  # type of object
print(sys.getsizeof(val3))  # eize of flont ohjeet in hutee
# val3 is an instance of complex
print(val3, " is complex?", isinstance(val3, complex))
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %% [markdown]
# # multiple Assignments

# %%
intvar, floatvar, strvar = 10, 2.57, "Python Language"  # Using commas to separat
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1 = p2 = p3 = p4 = 44  # ALl variables pointing to same value
print(p1, p2, p3, p4)
# Out:
# 44 44 44 44

# %%
r = 20
r, type(r), hex(id(r))
# Out:
# (20, int, '0x7ffb5d23a6d8')

# %%
str1 = 'HELLO WORLD'
str1
# Out:
# 'HELLO WORLD'

# %%
str1[0]
# Out:
# 'H'

# %%
str1[len(str1)-1]
# Out:
# 'D'

# %%
str1 = 'Hello'
del str1
str1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 str1 = 'Hello'
#       2 del str1
# ----> 3 str1
#
# NameError: name 'str1' is not defined
