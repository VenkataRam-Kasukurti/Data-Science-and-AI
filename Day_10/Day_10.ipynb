# %%
x = input()
x

# %%
x = input()
y = input()

z = x+y
print(z)

# %%
st = input('enter a string')
print(st)

# %%
result = eval(input('enter an expre'))  # eval for the expressin
print(result)

# %%
import sys
x = int(sys.argv[1])
y = int(sys.argv[2])

m = z + y

print(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 import sys
# ----> 2 x = int(sys.argv[1])
#       3 y = int(sys.argv[2])
#       4
#       5 m = z + y
#
# ValueError: invalid literal for int() with base 10: '--f=c:\\Users\\kasukurv3155\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3549c86bce57d345467875416737ee29748eb0b0c.json'

# %%
1- variable syntax -- var = value | value called as datatype
2- data type
3- type casting
4- python basic operator ( arithment, assignment, relation, unary, logical)
5- bitwise operat(complement, and, or, xor, left shift, right shift)
6- bitwise number system
7- pkg, module, inbuild function - print, len, id, max, min,
8- print() with format method, print{} no of variable == no. of curly
9- data structure - list, tuple, set, dict, range
10- math module
11- keywords from, as, import
12- optimization ( reduce the code lines to speed up your application)
13- parameter vs hyperparameter
14- input() | number, string, expression is eval
15- string question
16- work python code using cli & using sys . argv
