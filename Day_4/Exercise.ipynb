# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10, 20)
print('python')
print(10, 20, 'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1+num2
print(add)
# Out:
# 50

# %%
num1 = 20
num2 = 30
add = num1+num2
print('The addition of', num1, 'and', num2, 'is=', add)
# Out:
# The addition of 20 and 30 is= 50

# %%
name = 'Python'
age = 20
city = 'hyd'
print('hello my name is', name, 'and i am', age, 'years old from', city)
# Out:
# hello my name is Python and i am 20 years old from hyd

# %%
# Arithmetic operators
a = 5
b = 2
sum_result = a + b
difference_result = a - b
product_result = a * b
division_result = a / b

# %%
# Comparison operators
is_equal = a == b
is_not_equal = a != b
is_greater_than = a > b
is_less_than = a < b

# %%
# Logical operators
logical_and = (a > 0) and (b > 0)
logical_or = (a > 0) or (b > 0)
logical_not = not (a > 0)

print("Arithmetic Operators:")
print("Sum:", sum_result)
print("Difference:", difference_result)
print("Product:", product_result)
print("Division:", division_result)

print("\nComparison Operators:")
print("Is Equal:", is_equal)
print("Is Not Equal:", is_not_equal)
print("Is Greater Than:", is_greater_than)
print("Is Less Than:", is_less_than)

print("\nLogical Operators:")
print("Logical AND:", logical_and)
print("Logical OR:", logical_or)
print("Logical NOT:", logical_not)
# Out:
# Arithmetic Operators:
# Sum: 7
# Difference: 3
# Product: 10
# Division: 2.5
#
# Comparison Operators:
# Is Equal: False
# Is Not Equal: True
# Is Greater Than: True
# Is Less Than: False
#
# Logical Operators:
# Logical AND: True
# Logical OR: True
# Logical NOT: False

# %%
# Unary minus (-) operator
number = 10
result = -number
print("Unary Minus Operator:", result)

# Unary plus (+) operator
result = +number
print("Unary Plus Operator:", result)

# Logical NOT (!) operator
is_true = True
logical_not_result = not is_true
print("Logical NOT Operator:", logical_not_result)
# Out:
# Unary Minus Operator: -10
# Unary Plus Operator: 10
# Logical NOT Operator: False

# %%
# Binary addition (+) operator
a = 5
b = 3
addition_result = a + b
print("Binary Addition Operator:", addition_result)

# Binary multiplication (*) operator
multiplication_result = a * b
print("Binary Multiplication Operator:", multiplication_result)

# Logical AND (&) operator
bitwise_and_result = a & b
print("Bitwise AND Operator:", bitwise_and_result)
# Out:
# Binary Addition Operator: 8
# Binary Multiplication Operator: 15
# Bitwise AND Operator: 1

# %%
# Arithmetic operators
a = 10
b = 3

# Addition
addition_result = a + b

# Subtraction
subtraction_result = a - b

# Multiplifation
multiplication_result = a * b

# Division
division_result = a / b

# Modulus
modulus_result = a % b

# Exponentiation
exponentiation_result = a ** b

print("Addition Result:", addition_result)
print("Subtraction Result:", subtraction_result)
print("Multiplication Result:", multiplication_result)
print("Division Result:", division_result)
print("Modulus Result:", modulus_result)
print("Exponentiation Result:", exponentiation_result)
# Out:
# Addition Result: 13
# Subtraction Result: 7
# Multiplication Result: 30
# Division Result: 3.3333333333333335
# Modulus Result: 1
# Exponentiation Result: 1000

# %%
# Modulus operator example
number = 15
divisor = 7

# Calculate remainder using modulus
remainder = number % divisor

print(f"The remainder of {number} divided by {divisor} is: {remainder}")
# Out:
# The remainder of 15 divided by 7 is: 1

# %%
# Example with == operator
list1 = [1, 2, 3]
list2 = [1, 2, 3]

# == compares values
result1 = list1 == list2

# Example with is operator
list3 = [1, 2, 3]
list4 = [1, 2, 3]

# is checks if objects refer to the same memory location
result2 = list3 is list4

print("Using == Operator:", result1)
print("Using is Operator:", result2)
# Out:
# Using == Operator: True
# Using is Operator: False

# %%
# Example with and operator
num1 = 5
num2 = 10

# and returns True if both conditions are True
result1 = (num1 > 0) and (num2 > 0)

# Example with or operator
num3 = -5
num4 = 10

# or returns True if at least one condition is True
result2 = (num3 > 0) or (num4 > 0)

# %% [markdown]
# PYTHON OPERATORS AND EXPRESSIONS:
# INTERVIEW QUESTIONS.

# %% [markdown]
# 1. What is an operator in Python?
#
# 2. Explain the difference between unary and binary operators with examples.
#
# 3. What is the order of precedence in Python operators?
#
# 4. Discuss the role of arithmetic operators in Python.
#
# 5. Explain the concept of modulus and its use in Python.
#
# 6. Differentiate between the == and is operators in Python.
#
# 7. How do you use the and, or, and not logical operators in Python?
#
# 8. Discuss the purpose of the bitwise operators (&, |, ^, << , >>) in Python.
#
# 9. Explain the use of the membership operators (in and not in) in Python.
#
# 10. What is the purpose of the identity operators (is and is not) in Python?
#
# 11. Discuss the role of the ternary conditional operator (x if condition else y) in
#     Pvthon.
#
# 12. How are comparison operators (<, >, <= , >=, != , == ) used in Python?
#
# 13. Explain the use of assignment operators (=, +=, -= , \*= , /=) in Python.
#
# 14. What is the purpose of the in keyword when used with strings and lists?
#
# 15. Discuss the user of the slice operator (:) in Python.
#
# 16. How can you use the \*\* operator for exponentiation in Python?
#
# 17. Explain the concept of the // operator in Python.
#
# 18. Discuss the use of the != and \*= operaters with examples.
#
# 19. How do you use the not operator to negate a boolean value in Python?
#
# 20. Explain the purpose of the () operator in Python and give examples of its use.
#
# 21. What are the basic arithmetic operators in Python?
#
# 22. What is the difference between integer division (//) and regular division (/)?
#
# 23. What happens when you divide a number by zero in Python?
#
# 24. How do you calculate the remainder of a division in Python?
#
# 25. What is the order of operations (precedence) in Python expressions?
#
# 26. What are the basic comparison operators in Python?
#
# 27. How do you compare strings using comparison operators?
#
# 28. What is the difference between single (=) and double equal signs ( == ) in Python?
#     I
# 29. Can you compare different data types using comparison operators?
#
# 30. How do you check if a variable is None in Python?
#
# 31. What is an expression in Python?
#
# 32. What are logical operators in Python?
#
# 33. How do you prioritize logical operations in Python expressions?
#
# 34. What is short-circuiting in Python's logical operators?
#
# 35. How can short-circuiting be useful?
#
# 36. How can you control the order or operations in a complex expression?
#
# 37. What happen if you accedentlly omit parentheses in an expression?
#
# 38. How can you improve the readability of complex expressions?
#
# 39. What are augmented assignment operators in Python?
#
# 40. What are some best practices for using operators and expressions in Python?

# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10, 20)
print('Python')
print(10, 20, 'python')
# Out:
# 10
# 10 20
# Python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(add)
# Out:
# 50

# %%
print('The addition of', num1, 'and', num2, 'is=', add)
# Out:
# The addition of 20 and 30 is= 50

# %%
print('The addition of{}and{}is={}'.format(num1, num2, add))
# Out:
# The addition of20and30is=50

# %%
print(f'the addition of {num1} and {num2} is = {add}')
# Out:
# the addition of 20 and 30 is = 50

# %%
print('hello')
print('Good Morning')
# Out:
# hello
# Good Morning

# %%
print('hello', end='')
print('world good day')
# Out:
# helloworld good day

# %%
print('hello', 'hai', 'how are you', sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print(1, 2, end=' ')
print(3, '.', sep='')
# Out:
# 1 2 3.
