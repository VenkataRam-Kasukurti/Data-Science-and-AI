# %% [markdown]
# #indexing, Slicing

# %%
str = "Hello"

# %%
str
# Out:
# 'Hello'

# %%
len(str)
# Out:
# 5

# %%
str[1:3]
# Out:
# 'el'

# %% [markdown]
# #PYTHON OPERATORS

# %%
x1 = 10
y1 = 5

# %%
x1, y1 = 10, 5

# %%
a, b = 6, 9

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# -3

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a//b
# Out:
# 0

# %%
a * b
# Out:
# 54

# %%
a ** b
# Out:
# 10077696

# %%
a % b
# Out:
# 6

# %%
a += 2

# %%
a
# Out:
# 8

# %%
a *= 2

# %%
a
# Out:
# 16

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'
