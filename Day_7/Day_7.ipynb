# %%
l = (1, 2, 3,)

# %%
type(l)
# Out:
# tuple

# %%
l.count(1)
# Out:
# 1

# %%
len(l)
# Out:
# 3

# %%
l[0]
# Out:
# 1

# %%
l[0] = 100  # tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l[0] = 100  # tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # list
#
# - mutable
# - duplicate is allowed
# - append(), copy(), insert(), extend(), pop()
# - remove the element
# - list is growable
# - multiple data type in a list
# - indexing & slicing is allowed
#
# # Tuple
#
# - immutable ( unchangeable)
# - duplication is allowed
# - remove is not allowed
# - only 2 function will work (.index, .count)
#
# I

# %%
# sets
s = {}
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s1 = set()
s1
# Out:
# set()

# %%
s2 = {90, 10, 50, 40, 50, 100, 90}

# %%
s2
# Out:
# {10, 40, 50, 90, 100}

# %%
type(s2)
# Out:
# set

# %%
s2.add(101, 120)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 s2.add(101, 120)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
s3 = s2.copy()
s3
# Out:
# {10, 40, 50, 90, 100}
